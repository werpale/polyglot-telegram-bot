# %% [markdown]
# <a href="https://colab.research.google.com/github/werpale/polyglot-telegram-bot/blob/main/Emotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section

# %%
import zipfile, os

zip_path = "OrganizeYourMusic-master.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall()

os.listdir("OrganizeYourMusic-master")
# Out:
# ['web', 'README.md', '.gitignore', 'CLAUDE.md']

# %%
# %cd /content/drive/MyDrive/emotify
# !ls
# Out:
# /content/drive/MyDrive/emotify
# config.js  index.html  server.py  spotify.js

# %%
# %cd /content/drive/MyDrive/emotify
# Out:
# /content/drive/MyDrive/emotify

# %% [markdown]
# # Streamlit

# %%
# !pip install streamlit
import streamlit as st
import pandas as pd

df = pd.read_json("tracks.json")

st.title("Music Analyzer")

st.scatter_chart(df, x="energy", y="danceability")
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8420/3149860437.py in <cell line: 0>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_json("tracks.json")
#       6
#       7 st.title("Music Analyzer")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...

# %% [markdown]
# # Flask

# %%
pip install flask pandas requests pyngrok

# %%
# !python server.py

# %%
# !python -m http.server 8000
# Out:
# Serving HTTP on 0.0.0.0 port 8000 (http://0.0.0.0:8000/) ...
#
# Keyboard interrupt received, exiting.

# %% [markdown]
# # Server config
# [link text](https://)

# %%
# !python -m http.server 8001 &
# Out:
# Serving HTTP on 0.0.0.0 port 8001 (http://0.0.0.0:8001/) ...
# 127.0.0.1 - - [15/Mar/2026 19:38:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2026 19:38:25] code 404, message File not found
# 127.0.0.1 - - [15/Mar/2026 19:38:25] "GET /style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Mar/2026 19:38:25] "GET /spotify.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2026 19:38:25] code 404, message File not found
# 127.0.0.1 - - [15/Mar/2026 19:38:25] "GET /analyzer.js HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Mar/2026 19:38:25] "GET /config.js HTTP/1.1" 200 -

# %%
# !lsof -i:8001
# Out:
# COMMAND  PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# python3 3265 root    3u  IPv4 103891      0t0  TCP *:8001 (LISTEN)

# %%
# !kill -9 3265

# %% [markdown]
# # NGrok

# %%
# !pip install pyngrok

# %%
ngrok.kill()

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3AujHRjLn7lZ0Qb9Edps1FRgzJ1_PxLzAsXDiAgRCk1FxwVK")

# %%
from pyngrok import ngrok

# Terminate any existing ngrok tunnels immediately before connecting
ngrok.kill()

public_url = ngrok.connect(8001)
print(public_url)
# Out:
# NgrokTunnel: "https://postumbonal-punchiest-valerie.ngrok-free.dev" -> "http://localhost:8001"

# %% [markdown]
# # New Section
